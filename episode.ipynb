# %%
import pandas as pd
import numpy as np
from itertools import combinations, permutations

# %% [markdown]
# #### Serial Episode - Parallel Episode - Non-Serial/Parallel Episode
#
# **Serial Episode** : Comprises of a sequence of events that occur in a fixed order. An important note is that in order for an event to begin it's precedent event must be completed.
#
#     Wake Up -> Brush Teeth -> Eat Breakfast
#
# **Parallel Episode** : Comprises of a set of events that can occur in any order and/or simultaneously.
#
#     Cut Vegetables -> Watch Recipe Video -> Salt Boiling Water
#
# **Non-Serial Episode** : Comprises of a set of events that can occur in any order but **not** simultaneously
#
#     Shop Groceries -> Work On Project -> Eat Dinner

# %% [markdown]
# #### MINEPI vs WINEPI
#
# MINEPI (Minimum Description Length-based Episodic Pattern Mining) and WINEPI (Weighted Minimum Description Length-based Episodic Pattern Mining) are algorithms for mining episodic patterns from sequential data.
#
# Key differences:
#
# 1. MINEPI is based on the MDL (Minimum Description Principle) that finds patterns that can compress the data the most. Conversly, WINEPI is based on the weighted MDL principle that considers the compression of the data as much as the importance of the pattern.
#
# 2. MINEPI assumes that all episodes are unweighted and hence contribute equally to the sequence. However, WINEPI allows for weighted episodes where their importance is indicated by a weight.
#
# 3. MINEPI searches for patterns using BFS (Breadth-First Search) while WINEPI using beam search. Therefore, WINEPI may be more computationally efficient but some patterns may only be discovered using MINEPI.
#
# 4. MINEPI is more robust to data noise since it adopts a threshold based approach to filter out statistically insignificant patterns. Inversly, due to the fact that WINEPI assigns weights to the episodes, it is more sensitive to outliers.

# %% [markdown]
# Let's load our data into a DataFrame object

# %%
df_loan = pd.read_csv('Artificial - Loan Process.csv')
df_loan
# Out:
#          case                 event         completeTime
# 0     trace 0  register application  2013-04-16 10:08:02
# 1     trace 0          check credit  2013-04-16 10:16:03
# 2     trace 0    calculate capacity  2013-04-16 10:16:28
# 3     trace 0          check system  2013-04-16 10:20:25
# 4     trace 0                accept  2013-04-16 10:21:30
# ..        ...                   ...                  ...
# 585  trace 99  register application  2013-04-16 18:30:02
# 586  trace 99    calculate capacity  2013-04-16 18:39:07
# 587  trace 99          check credit  2013-04-16 18:48:13
# 588  trace 99                reject  2013-04-16 18:50:59
# 589  trace 99  send decision e-mail  2013-04-16 18:55:34
#
# [590 rows x 3 columns]

# %% [markdown]
# We detect that the *completeTime* column contains timestamps so it is natural to check if it is of the correct data type.

# %%
df_loan.dtypes
# Out:
# case            object
# event           object
# completeTime    object
# dtype: object

# %% [markdown]
# We detect that it's a string so we will convert it to a time series and use it to create another column of unix timestamps. We do this to preserve the timestamp integrity but convert it to a format than can be processed and compared to.

# %%
df_loan['completeTime_unix'] = pd.to_datetime(df_loan['completeTime']).apply(lambda x: int(x.timestamp()))
df_loan
# Out:
#          case                 event         completeTime  completeTime_unix
# 0     trace 0  register application  2013-04-16 10:08:02         1366106882
# 1     trace 0          check credit  2013-04-16 10:16:03         1366107363
# 2     trace 0    calculate capacity  2013-04-16 10:16:28         1366107388
# 3     trace 0          check system  2013-04-16 10:20:25         1366107625
# 4     trace 0                accept  2013-04-16 10:21:30         1366107690
# ..        ...                   ...                  ...                ...
# 585  trace 99  register application  2013-04-16 18:30:02         1366137002
# 586  trace 99    calculate capacity  2013-04-16 18:39:07         1366137547
# 587  trace 99          check credit  2013-04-16 18:48:13         1366138093
# 588  trace 99                reject  2013-04-16 18:50:59         1366138259
# 589  trace 99  send decision e-mail  2013-04-16 18:55:34         1366138534
#
# [590 rows x 4 columns]

# %% [markdown]
# We sort our episodes based on their timestamps.

# %%
df_loan.sort_values(by='completeTime', ascending=True, inplace=True)
df_loan.reset_index(inplace=True)
df_loan.drop(columns='index', inplace=True)
df_loan
# Out:
#          case                 event         completeTime  completeTime_unix
# 0     trace 0  register application  2013-04-16 10:08:02         1366106882
# 1     trace 1  register application  2013-04-16 10:10:02         1366107002
# 2     trace 2  register application  2013-04-16 10:15:42         1366107342
# 3     trace 0          check credit  2013-04-16 10:16:03         1366107363
# 4     trace 1          check credit  2013-04-16 10:16:07         1366107367
# ..        ...                   ...                  ...                ...
# 585  trace 99          check credit  2013-04-16 18:48:13         1366138093
# 586  trace 98  send decision e-mail  2013-04-16 18:50:47         1366138247
# 587  trace 99                reject  2013-04-16 18:50:59         1366138259
# 588  trace 97  send decision e-mail  2013-04-16 18:51:36         1366138296
# 589  trace 99  send decision e-mail  2013-04-16 18:55:34         1366138534
#
# [590 rows x 4 columns]

# %% [markdown]
# We assign each different event to an integer for comparability purposes.

# %%
event_dict = {'register application' : '1', 'check credit' : '2', 'calculate capacity' : '3', 
              'check system' : '4', 'accept' : '5', 'send decision e-mail' : '6', 'reject' : '7'}

for index in df_loan.index:
    df_loan.at[index, 'event_num'] = event_dict[df_loan.at[index, 'event']] 
df_loan
# Out:
#          case                 event         completeTime  completeTime_unix  \
# 0     trace 0  register application  2013-04-16 10:08:02         1366106882
# 1     trace 1  register application  2013-04-16 10:10:02         1366107002
# 2     trace 2  register application  2013-04-16 10:15:42         1366107342
# 3     trace 0          check credit  2013-04-16 10:16:03         1366107363
# 4     trace 1          check credit  2013-04-16 10:16:07         1366107367
# ..        ...                   ...                  ...                ...
# 585  trace 99          check credit  2013-04-16 18:48:13         1366138093
# 586  trace 98  send decision e-mail  2013-04-16 18:50:47         1366138247
# 587  trace 99                reject  2013-04-16 18:50:59         1366138259
# 588  trace 97  send decision e-mail  2013-04-16 18:51:36         1366138296
# 589  trace 99  send decision e-mail  2013-04-16 18:55:34         1366138534
#
#     event_num
# 0           1
# 1           1
# 2           1
# 3           2
# 4           2
# ..        ...
# 585         2
# 586         6
# 587         7
# 588         6
# 589         6
#
# [590 rows x 5 columns]

# %% [markdown]
# We create a list of tuples in the format of (timestamp, event)

# %%
episodes = (df_loan[['completeTime_unix', 'event_num']].to_records(index=False)).tolist()
episodes
# Out:
# [(1366106882, '1'),
#  (1366107002, '1'),
#  (1366107342, '1'),
#  (1366107363, '2'),
#  (1366107367, '2'),
#  (1366107381, '3'),
#  (1366107388, '3'),
#  (1366107596, '1'),
#  (1366107611, '4'),
#  (1366107625, '4'),
from episode_mining.winepi import WINEPI, WinEpiRules

winepi_miner = WINEPI(sequence=episodes, episode_type='parallel')

# %% [markdown]
# We set the minimum support threshold to 0.001

# %%
freqItems, suppData = winepi_miner.WinEpi(width=10, step=4, minFrequent=0.001)

# %%
winepiRules = WinEpiRules(freqItems, suppData, width=4, minConfidence=0.05)
ruleList = winepiRules.generateRules()
winepiRules.printRules(ruleList)
# Out:
# WINEPIRule: ['7'] ==> ['4', '7'] [4] [0.0012634238787113076, 0.05128205128205128]
# WINEPIRule: ['7'] ==> ['1', '7'] [4] [0.0013897662665824384, 0.05641025641025641]

# %% [markdown]
# We experiment with the hyperparameter values and the results they produce.

# %%
freqItems, suppData = winepi_miner.WinEpi(width=10, step=4, minFrequent=0.0006)

# %%
winepiRules = WinEpiRules(freqItems, suppData, width=4, minConfidence=0.04)
ruleList = winepiRules.generateRules()
winepiRules.printRules(ruleList)
# Out:
# WINEPIRule: ['1'] ==> ['1', '2'] [4] [0.0013897662665824384, 0.045081967213114756]
# WINEPIRule: ['2'] ==> ['1', '2'] [4] [0.0013897662665824384, 0.04526748971193415]
# WINEPIRule: ['4'] ==> ['4', '7'] [4] [0.0012634238787113076, 0.04444444444444444]
# WINEPIRule: ['7'] ==> ['4', '7'] [4] [0.0012634238787113076, 0.05128205128205128]
# WINEPIRule: ['1'] ==> ['1', '7'] [4] [0.0013897662665824384, 0.045081967213114756]
# WINEPIRule: ['7'] ==> ['1', '7'] [4] [0.0013897662665824384, 0.05641025641025641]
# WINEPIRule: ['4'] ==> ['4', '6'] [4] [0.001137081490840177, 0.04]
# WINEPIRule: ['1'] ==> ['1', '4'] [4] [0.0013897662665824384, 0.045081967213114756]
# WINEPIRule: ['4'] ==> ['1', '4'] [4] [0.0013897662665824384, 0.048888888888888885]
# WINEPIRule: ['1'] ==> ['1', '3'] [4] [0.0013897662665824384, 0.045081967213114756]
# WINEPIRule: ['3'] ==> ['1', '3'] [4] [0.0013897662665824384, 0.04453441295546559]

# %%
freqItems, suppData = winepi_miner.WinEpi(width=10, step=4, minFrequent=0.0006)

# %%
winepiRules = WinEpiRules(freqItems, suppData, width=4, minConfidence=0.01)
ruleList = winepiRules.generateRules()
winepiRules.printRules(ruleList)
# Out:
# WINEPIRule: ['3'] ==> ['3', '7'] [4] [0.0006317119393556538, 0.020242914979757085]
# WINEPIRule: ['7'] ==> ['3', '7'] [4] [0.0006317119393556538, 0.02564102564102564]
# WINEPIRule: ['2'] ==> ['2', '3'] [4] [0.0007580543272267846, 0.024691358024691357]
# WINEPIRule: ['3'] ==> ['2', '3'] [4] [0.0007580543272267846, 0.024291497975708502]
# WINEPIRule: ['3'] ==> ['3', '4'] [4] [0.0008843967150979153, 0.02834008097165992]
# WINEPIRule: ['4'] ==> ['3', '4'] [4] [0.0008843967150979153, 0.03111111111111111]
# WINEPIRule: ['1'] ==> ['1', '2'] [4] [0.0013897662665824384, 0.045081967213114756]
# WINEPIRule: ['2'] ==> ['1', '2'] [4] [0.0013897662665824384, 0.04526748971193415]
# WINEPIRule: ['2'] ==> ['2', '6'] [4] [0.0008843967150979153, 0.028806584362139915]
# WINEPIRule: ['6'] ==> ['2', '6'] [4] [0.0008843967150979153, 0.028455284552845527]
# WINEPIRule: ['3'] ==> ['3', '6'] [4] [0.0008843967150979153, 0.02834008097165992]
# WINEPIRule: ['6'] ==> ['3', '6'] [4] [0.0008843967150979153, 0.028455284552845527]
# WINEPIRule: ['6'] ==> ['6', '7'] [4] [0.0006317119393556538, 0.02032520325203252]
# WINEPIRule: ['7'] ==> ['6', '7'] [4] [0.0006317119393556538, 0.02564102564102564]
# WINEPIRule: ['4'] ==> ['4', '7'] [4] [0.0012634238787113076, 0.04444444444444444]
# WINEPIRule: ['7'] ==> ['4', '7'] [4] [0.0012634238787113076, 0.05128205128205128]
# WINEPIRule: ['1'] ==> ['1', '7'] [4] [0.0013897662665824384, 0.045081967213114756]
# WINEPIRule: ['7'] ==> ['1', '7'] [4] [0.0013897662665824384, 0.05641025641025641]
# WINEPIRule: ['4'] ==> ['4', '6'] [4] [0.001137081490840177, 0.04]
# WINEPIRule: ['6'] ==> ['4', '6'] [4] [0.001137081490840177, 0.03658536585365854]
# WINEPIRule: ['1'] ==> ['1', '4'] [4] [0.0013897662665824384, 0.045081967213114756]
# WINEPIRule: ['4'] ==> ['1', '4'] [4] [0.0013897662665824384, 0.048888888888888885]
# WINEPIRule: ['1'] ==> ['1', '3'] [4] [0.0013897662665824384, 0.045081967213114756]
# WINEPIRule: ['3'] ==> ['1', '3'] [4] [0.0013897662665824384, 0.04453441295546559]

# %% [markdown]
# Now we will implement MINEPI.

# %%
def createC1(sequence, step):
    C1 = {}
    for event in sequence:
        mo = tuple((event[0], event[0] + step)) # calc minimal occurrence (mo)
        evt1 = tuple(event[1])
        if evt1 in C1: # if event exists in C1
            if mo not in C1[evt1]: # if mo not exists in event's set of mo
                C1[evt1].add(mo)
        else: C1[evt1] = set((mo,))
    return C1

# %%
def createLargeEpisodeSet(Ck, min_fr):
    Lk = Ck.copy()
    for episode in Ck:
        if len(Ck[episode]) < min_fr: # if number of mo < min_fr
            del Lk[episode]
    return Lk

# %%
def checkSubsetFrequency(candidate, Lk, k):
    if k > 1:    
        subsets = list(combinations(candidate, k))
    else:
        return True
    for elem in subsets:
        if not elem in Lk: #elem is tuple
            return False
    return True

# %%
def createCandidates(Lk, L1, k, max_width):
    # create candidates list
    candidatesK = [] #candidates list
    generatedCans = [] 
    lkKeys = sorted(set([item for t in Lk for item in t])) # get all episodes and sort / Lk:get all keys
    generatedCans = list(combinations(lkKeys, k))
    for can in generatedCans:
        if checkSubsetFrequency(can, Lk, k-1): #if all subsets of can is frequent / Lk:get all keys
            candidatesK.append(can)
    # create minimal occurrence of candidates
    if len(candidatesK) == 0: # if candidates list is null
        return dict()
    else:
        Ck = {}
        if k == 2: #candidate 2
            for can in candidatesK: # can is tuple
                Ck[can] = set()
                for mok in Lk[tuple(can[0])]:
                    for mo1 in L1[tuple(can[1])]:
                        tsmin = min(mok[0], mo1[0])
                        temax = max(mok[1], mo1[1])
                        # temax - tsmin <= max_width
                        if temax - tsmin <= max_width:
                            Ck[can].add(tuple((tsmin, temax)))
        else: #candidate > 2
            for can in candidatesK: # can is tuple
                Ck[can] = set()
                for mok in Lk[can[:-1]]:
                    for mo1 in L1[tuple(can[-1])]:
                        tsmin = min(mok[0], mo1[0])
                        temax = max(mok[1], mo1[1])
                        # temax - tsmin <= max_width
                        if temax - tsmin <= max_width:
                            Ck[can].add(tuple((tsmin, temax)))
        # recheck minimal occurrence is minimal
        for episode, setOfMOs in Ck.items():
            rem = set() #remove set
            for mo1 in setOfMOs:
                for mo2 in setOfMOs.difference(mo1):
                    # mo1[0] is mo1.ts, mo2[0] is mo2.ts, mo1[1] is mo1.te, mo2[1] is mo2.te
                    if (mo1[0]==mo2[0] and mo1[1] < mo2[1]) or (mo1[0] > mo2[0] and mo1[1] == mo2[1]) or (mo1[0] > mo2[0] and mo1[1] < mo2[1]):
                        rem.add(mo2)
            Ck[episode] = setOfMOs.difference(rem)
        return Ck

# %%
def MinEpi(sequence, max_width, step, minFrequent):
    C1 = createC1(sequence, step)
    L1 = createLargeEpisodeSet(C1, minFrequent)
    L = [L1]
    k = 2
    while (len(L[k-2]) > 0):
        Ck = createCandidates(L[k-2], L1, k, max_width)
        Lk = createLargeEpisodeSet(Ck, minFrequent)
        L.append(Lk)
        k += 1
    #remove empty last itemset from L
    if L[-1] == {}:
        L.pop()
    return L

L = MinEpi(episodes, max_width=5, step=1, minFrequent=2)
L
# Out:
# [{('1',): {(1366106882, 1366106883),
#    (1366107002, 1366107003),
#    (1366107342, 1366107343),
#    (1366107596, 1366107597),
#    (1366108123, 1366108124),
#    (1366108408, 1366108409),
#    (1366108507, 1366108508),
#    (1366108706, 1366108707),
#    (1366109243, 1366109244),
#    (1366109249, 1366109250),
#    (1366109372, 1366109373),
#    (1366109466, 1366109467),
#    (1366109665, 1366109666),
#    (1366110134, 1366110135),
#    (1366110327, 1366110328),
#    (1366110577, 1366110578),
#    (1366111051, 1366111052),
#    (1366111153, 1366111154),
#    (1366111530, 1366111531),
#    (1366112046, 1366112047),
#    (1366112350, 1366112351),
#    (1366112494, 1366112495),
#    (1366112634, 1366112635),
#    (1366113232, 1366113233),
#    (1366113383, 1366113384),
#    (1366113534, 1366113535),
#    (1366114103, 1366114104),
#    (1366114502, 1366114503),
#    (1366114941, 1366114942),
#    (1366114998, 1366114999),
#    (1366115039, 1366115040),
#    (1366115496, 1366115497),
#    (1366115623, 1366115624),
#    (1366115988, 1366115989),
#    (1366116178, 1366116179),
#    (1366116312, 1366116313),
#    (1366116801, 1366116802),
#    (1366117163, 1366117164),
#    (1366117349, 1366117350),
#    (1366117427, 1366117428),
#    (1366117555, 1366117556),
#    (1366117673, 1366117674),
#    (1366118263, 1366118264),
#    (1366118751, 1366118752),
#    (1366118935, 1366118936),
#    (1366119316, 1366119317),
#    (1366119448, 1366119449),
#    (1366120022, 1366120023),
#    (1366120372, 1366120373),
#    (1366120734, 1366120735),
#    (1366121175, 1366121176),
#    (1366121234, 1366121235),
#    (1366121673, 1366121674),
#    (1366122114, 1366122115),
#    (1366122640, 1366122641),
#    (1366122998, 1366122999),
#    (1366123509, 1366123510),
#    (1366124102, 1366124103),
#    (1366124260, 1366124261),
#    (1366124844, 1366124845),
#    (1366125066, 1366125067),
#    (1366125368, 1366125369),
#    (1366125668, 1366125669),
#    (1366126100, 1366126101),
#    (1366126586, 1366126587),
#    (1366126932, 1366126933),
#    (1366132029, 1366132030),
#    (1366132062, 1366132063),
#    (1366132128, 1366132129),
#    (1366132474, 1366132475),
#    (1366133009, 1366133010),
#    (1366133503, 1366133504),
#    (1366133725, 1366133726),
#    (1366134382, 1366134383),
#    (1366134403, 1366134404),
#    (1366134462, 1366134463),
#    (1366135073, 1366135074),
#    (1366136185, 1366136186),
#    (1366136300, 1366136301),
#    (1366136589, 1366136590),
#    (1366137216, 1366137217),
#    (1366137345, 1366137346),
#    (1366137798, 1366137799),
#    (1366137837, 1366137838),
#    (1366138259, 1366138260)}},
#  {('1', '2'): {(1366117555, 1366117558),
#    (1366119314, 1366119317),
#    (1366126582, 1366126587),
#    (1366127061, 1366127063)},
#   ('1', '3'): {(1366108121, 1366108124),
#    (1366110577, 1366110581),
#    (1366112350, 1366112354),
#    (1366117673, 1366117676),
#    (1366135940, 1366135943)},
#   ('1', '4'): {(1366127277, 1366127279), (1366127697, 1366127702)},
#   ('1', '6'): {(1366113383, 1366113384), (1366126584, 1366126587)},
#   ('1', '7'): {(1366109466, 1366109470),
#    (1366111048, 1366111052),
#    (1366113229, 1366113233),
#    (1366115496, 1366115501)},
#   ('2', '3'): {(1366123799, 1366123800), (1366128409, 1366128411)},
#   ('2', '6'): {(1366116508, 1366116513),
#    (1366123499, 1366123503),
#    (1366126582, 1366126585)},
#   ('3', '5'): {(1366108967, 1366108972), (1366108971, 1366108976)},
#   ('3', '6'): {(1366114400, 1366114401), (1366129140, 1366129144)},
#   ('3', '7'): {(1366129698, 1366129700), (1366130828, 1366130832)},
#   ('4', '6'): {(1366116252, 1366116256),
#    (1366129520, 1366129522),
#    (1366131187, 1366131188)},
#   ('4', '7'): {(1366111045, 1366111049),
#    (1366112551, 1366112553),
#    (1366117156, 1366117158),
#    (1366118290, 1366118294),
#    (1366118293, 1366118296)}}]

# %%
def isAlphaOccurInBeta(mob, mos_alpha): #mo_beta include (mo_beta_ts) and (mo_beta_ts + width2)
    for moa in mos_alpha:
        if mob[0] <= moa[0] and moa[1] <= mob[1]:
            return True
    return False

# %%
def calcConfidence(mos_beta, wid1, mos_alpha, wid2):
    denominator = 0.0
    numerator = 0
    for mob in mos_beta:
        #te - ts <= width1
        if mob[1] - mob[0] <= wid1:
            denominator += 1
            #number of mo_beta [mob.ts, mob.ts + wid2) contains mo_alpha is numerator
            if isAlphaOccurInBeta((mob[0], mob[0] + wid2), mos_alpha):
                numerator += 1
    if denominator == 0:
        return 0
    else:  
        return numerator/denominator

# %%
def calcSupport(mos_alpha, wid2):
    support = 0
    for moa in mos_alpha:
        #te - ts <= width2
        if moa[1] - moa[0] <= wid2:
            support += 1
    return support

# %%
def generateRules(L, max_width, step, minConf):
        #calculate time bound W
        time_bound = list(range(step, max_width, step))
        time_bound.append(max_width)
        #generate all rules\n",
        for i in range(1, len(L)): #only get the sets with two or more items\n",
            for episode in L[i]: #for each episode in a level\n",
                for j in range(1, i+1): # i+1 equal to length of an episode, so j is the length of lhs\n",
                    lhsList = list(combinations(episode, j))
                    for lhs in lhsList: #each left-hand-side\n",
                        for rightWid in time_bound: #each time bound of rhs\n",
                            for leftWid in time_bound: #each time bound of lhs\n",
                                #index of L is the episode length-1\n",
                                conf = calcConfidence(L[j-1][lhs], leftWid, L[i][episode], rightWid)
                                if conf >= minConf:
                                    event1 = ([key for key in event_dict.keys() if event_dict[key] == list(lhs)[0]])
                                    events2 = [key for key, value in event_dict.items() if value in list(episode)]
                                    print(event1,f' [{leftWid}] ==> {events2}, [{rightWid}] [{calcSupport(L[i][episode], rightWid)}, {conf}]')

# %%
generateRules(L, 5, 1, 0.005)
# Out:
# ['register application']  [1] ==> ['register application', 'check credit'], [3] [3, 0.01]
# ['register application']  [2] ==> ['register application', 'check credit'], [3] [3, 0.01]
# ['register application']  [3] ==> ['register application', 'check credit'], [3] [3, 0.01]
# ['register application']  [4] ==> ['register application', 'check credit'], [3] [3, 0.01]
# ['register application']  [5] ==> ['register application', 'check credit'], [3] [3, 0.01]
# ['register application']  [1] ==> ['register application', 'check credit'], [4] [3, 0.01]
# ['register application']  [2] ==> ['register application', 'check credit'], [4] [3, 0.01]
# ['register application']  [3] ==> ['register application', 'check credit'], [4] [3, 0.01]
# ['register application']  [4] ==> ['register application', 'check credit'], [4] [3, 0.01]
# ['register application']  [5] ==> ['register application', 'check credit'], [4] [3, 0.01]
# ['register application']  [1] ==> ['register application', 'check credit'], [5] [4, 0.01]
# ['register application']  [2] ==> ['register application', 'check credit'], [5] [4, 0.01]
# ['register application']  [3] ==> ['register application', 'check credit'], [5] [4, 0.01]
# ['register application']  [4] ==> ['register application', 'check credit'], [5] [4, 0.01]
# ['register application']  [5] ==> ['register application', 'check credit'], [5] [4, 0.01]
# ['check credit']  [1] ==> ['register application', 'check credit'], [2] [1, 0.01]
# ['check credit']  [2] ==> ['register application', 'check credit'], [2] [1, 0.01]
# ['check credit']  [3] ==> ['register application', 'check credit'], [2] [1, 0.01]
# ['check credit']  [4] ==> ['register application', 'check credit'], [2] [1, 0.01]
# ['check credit']  [5] ==> ['register application', 'check credit'], [2] [1, 0.01]
# ['check credit']  [1] ==> ['register application', 'check credit'], [3] [3, 0.02]
# ['check credit']  [2] ==> ['register application', 'check credit'], [3] [3, 0.02]
# ['check credit']  [3] ==> ['register application', 'check credit'], [3] [3, 0.02]
# ['check credit']  [4] ==> ['register application', 'check credit'], [3] [3, 0.02]
# ['check credit']  [5] ==> ['register application', 'check credit'], [3] [3, 0.02]
# ['check credit']  [1] ==> ['register application', 'check credit'], [4] [3, 0.02]
# ['check credit']  [2] ==> ['register application', 'check credit'], [4] [3, 0.02]
# ['check credit']  [3] ==> ['register application', 'check credit'], [4] [3, 0.02]
# ['check credit']  [4] ==> ['register application', 'check credit'], [4] [3, 0.02]
# ['check credit']  [5] ==> ['register application', 'check credit'], [4] [3, 0.02]
# ['check credit']  [1] ==> ['register application', 'check credit'], [5] [4, 0.03]
# ['check credit']  [2] ==> ['register application', 'check credit'], [5] [4, 0.03]
# ['check credit']  [3] ==> ['register application', 'check credit'], [5] [4, 0.03]
# ['check credit']  [4] ==> ['register application', 'check credit'], [5] [4, 0.03]
# ['check credit']  [5] ==> ['register application', 'check credit'], [5] [4, 0.03]
# ['register application']  [1] ==> ['register application', 'calculate capacity'], [3] [3, 0.01]
# ['register application']  [2] ==> ['register application', 'calculate capacity'], [3] [3, 0.01]
# ['register application']  [3] ==> ['register application', 'calculate capacity'], [3] [3, 0.01]
# ['register application']  [4] ==> ['register application', 'calculate capacity'], [3] [3, 0.01]
# ['register application']  [5] ==> ['register application', 'calculate capacity'], [3] [3, 0.01]
# ['register application']  [1] ==> ['register application', 'calculate capacity'], [4] [5, 0.03]
# ['register application']  [2] ==> ['register application', 'calculate capacity'], [4] [5, 0.03]
# ['register application']  [3] ==> ['register application', 'calculate capacity'], [4] [5, 0.03]
# ['register application']  [4] ==> ['register application', 'calculate capacity'], [4] [5, 0.03]
# ['register application']  [5] ==> ['register application', 'calculate capacity'], [4] [5, 0.03]
# ['register application']  [1] ==> ['register application', 'calculate capacity'], [5] [5, 0.03]
# ['register application']  [2] ==> ['register application', 'calculate capacity'], [5] [5, 0.03]
# ['register application']  [3] ==> ['register application', 'calculate capacity'], [5] [5, 0.03]
# ['register application']  [4] ==> ['register application', 'calculate capacity'], [5] [5, 0.03]
# ['register application']  [5] ==> ['register application', 'calculate capacity'], [5] [5, 0.03]
# ['calculate capacity']  [1] ==> ['register application', 'calculate capacity'], [3] [3, 0.02]
# ['calculate capacity']  [2] ==> ['register application', 'calculate capacity'], [3] [3, 0.02]
# ['calculate capacity']  [3] ==> ['register application', 'calculate capacity'], [3] [3, 0.02]
# ['calculate capacity']  [4] ==> ['register application', 'calculate capacity'], [3] [3, 0.02]
# ['calculate capacity']  [5] ==> ['register application', 'calculate capacity'], [3] [3, 0.02]
# ['calculate capacity']  [1] ==> ['register application', 'calculate capacity'], [4] [5, 0.02]
# ['calculate capacity']  [2] ==> ['register application', 'calculate capacity'], [4] [5, 0.02]
# ['calculate capacity']  [3] ==> ['register application', 'calculate capacity'], [4] [5, 0.02]
# ['calculate capacity']  [4] ==> ['register application', 'calculate capacity'], [4] [5, 0.02]
# ['calculate capacity']  [5] ==> ['register application', 'calculate capacity'], [4] [5, 0.02]
# ['calculate capacity']  [1] ==> ['register application', 'calculate capacity'], [5] [5, 0.02]
# ['calculate capacity']  [2] ==> ['register application', 'calculate capacity'], [5] [5, 0.02]
# ['calculate capacity']  [3] ==> ['register application', 'calculate capacity'], [5] [5, 0.02]
# ['calculate capacity']  [4] ==> ['register application', 'calculate capacity'], [5] [5, 0.02]
# ['calculate capacity']  [5] ==> ['register application', 'calculate capacity'], [5] [5, 0.02]
# ['register application']  [1] ==> ['register application', 'check system'], [2] [1, 0.01]
# ['register application']  [2] ==> ['register application', 'check system'], [2] [1, 0.01]
# ['register application']  [3] ==> ['register application', 'check system'], [2] [1, 0.01]
# ['register application']  [4] ==> ['register application', 'check system'], [2] [1, 0.01]
# ['register application']  [5] ==> ['register application', 'check system'], [2] [1, 0.01]
# ['register application']  [1] ==> ['register application', 'check system'], [3] [1, 0.01]
# ['register application']  [2] ==> ['register application', 'check system'], [3] [1, 0.01]
# ['register application']  [3] ==> ['register application', 'check system'], [3] [1, 0.01]
# ['register application']  [4] ==> ['register application', 'check system'], [3] [1, 0.01]
# ['register application']  [5] ==> ['register application', 'check system'], [3] [1, 0.01]
# ['register application']  [1] ==> ['register application', 'check system'], [4] [1, 0.01]
# ['register application']  [2] ==> ['register application', 'check system'], [4] [1, 0.01]
# ['register application']  [3] ==> ['register application', 'check system'], [4] [1, 0.01]
# ['register application']  [4] ==> ['register application', 'check system'], [4] [1, 0.01]
# ['register application']  [5] ==> ['register application', 'check system'], [4] [1, 0.01]
# ['register application']  [1] ==> ['register application', 'check system'], [5] [2, 0.01]
# ['register application']  [2] ==> ['register application', 'check system'], [5] [2, 0.01]
# ['register application']  [3] ==> ['register application', 'check system'], [5] [2, 0.01]
# ['register application']  [4] ==> ['register application', 'check system'], [5] [2, 0.01]
# ['register application']  [5] ==> ['register application', 'check system'], [5] [2, 0.01]
# ['check system']  [1] ==> ['register application', 'check system'], [5] [2, 0.011235955056179775]
# ['check system']  [2] ==> ['register application', 'check system'], [5] [2, 0.011235955056179775]
# ['check system']  [3] ==> ['register application', 'check system'], [5] [2, 0.011235955056179775]
# ['check system']  [4] ==> ['register application', 'check system'], [5] [2, 0.011235955056179775]
# ['check system']  [5] ==> ['register application', 'check system'], [5] [2, 0.011235955056179775]
# ['register application']  [1] ==> ['register application', 'send decision e-mail'], [1] [1, 0.01]
# ['register application']  [2] ==> ['register application', 'send decision e-mail'], [1] [1, 0.01]
# ['register application']  [3] ==> ['register application', 'send decision e-mail'], [1] [1, 0.01]
# ['register application']  [4] ==> ['register application', 'send decision e-mail'], [1] [1, 0.01]
# ['register application']  [5] ==> ['register application', 'send decision e-mail'], [1] [1, 0.01]
# ['register application']  [1] ==> ['register application', 'send decision e-mail'], [2] [1, 0.01]
# ['register application']  [2] ==> ['register application', 'send decision e-mail'], [2] [1, 0.01]
# ['register application']  [3] ==> ['register application', 'send decision e-mail'], [2] [1, 0.01]
# ['register application']  [4] ==> ['register application', 'send decision e-mail'], [2] [1, 0.01]
# ['register application']  [5] ==> ['register application', 'send decision e-mail'], [2] [1, 0.01]
# ['register application']  [1] ==> ['register application', 'send decision e-mail'], [3] [2, 0.01]
# ['register application']  [2] ==> ['register application', 'send decision e-mail'], [3] [2, 0.01]
# ['register application']  [3] ==> ['register application', 'send decision e-mail'], [3] [2, 0.01]
# ['register application']  [4] ==> ['register application', 'send decision e-mail'], [3] [2, 0.01]
# ['register application']  [5] ==> ['register application', 'send decision e-mail'], [3] [2, 0.01]
# ['register application']  [1] ==> ['register application', 'send decision e-mail'], [4] [2, 0.01]
# ['register application']  [2] ==> ['register application', 'send decision e-mail'], [4] [2, 0.01]
# ['register application']  [3] ==> ['register application', 'send decision e-mail'], [4] [2, 0.01]
# ['register application']  [4] ==> ['register application', 'send decision e-mail'], [4] [2, 0.01]
# ['register application']  [5] ==> ['register application', 'send decision e-mail'], [4] [2, 0.01]
# ['register application']  [1] ==> ['register application', 'send decision e-mail'], [5] [2, 0.01]
# ['register application']  [2] ==> ['register application', 'send decision e-mail'], [5] [2, 0.01]
# ['register application']  [3] ==> ['register application', 'send decision e-mail'], [5] [2, 0.01]
# ['register application']  [4] ==> ['register application', 'send decision e-mail'], [5] [2, 0.01]
# ['register application']  [5] ==> ['register application', 'send decision e-mail'], [5] [2, 0.01]
# ['send decision e-mail']  [1] ==> ['register application', 'send decision e-mail'], [1] [1, 0.01]
# ['send decision e-mail']  [2] ==> ['register application', 'send decision e-mail'], [1] [1, 0.01]
# ['send decision e-mail']  [3] ==> ['register application', 'send decision e-mail'], [1] [1, 0.01]
# ['send decision e-mail']  [4] ==> ['register application', 'send decision e-mail'], [1] [1, 0.01]
# ['send decision e-mail']  [5] ==> ['register application', 'send decision e-mail'], [1] [1, 0.01]
# ['send decision e-mail']  [1] ==> ['register application', 'send decision e-mail'], [2] [1, 0.01]
# ['send decision e-mail']  [2] ==> ['register application', 'send decision e-mail'], [2] [1, 0.01]
# ['send decision e-mail']  [3] ==> ['register application', 'send decision e-mail'], [2] [1, 0.01]
# ['send decision e-mail']  [4] ==> ['register application', 'send decision e-mail'], [2] [1, 0.01]
# ['send decision e-mail']  [5] ==> ['register application', 'send decision e-mail'], [2] [1, 0.01]
# ['send decision e-mail']  [1] ==> ['register application', 'send decision e-mail'], [3] [2, 0.02]
# ['send decision e-mail']  [2] ==> ['register application', 'send decision e-mail'], [3] [2, 0.02]
# ['send decision e-mail']  [3] ==> ['register application', 'send decision e-mail'], [3] [2, 0.02]
# ['send decision e-mail']  [4] ==> ['register application', 'send decision e-mail'], [3] [2, 0.02]
# ['send decision e-mail']  [5] ==> ['register application', 'send decision e-mail'], [3] [2, 0.02]
# ['send decision e-mail']  [1] ==> ['register application', 'send decision e-mail'], [4] [2, 0.02]
# ['send decision e-mail']  [2] ==> ['register application', 'send decision e-mail'], [4] [2, 0.02]
# ['send decision e-mail']  [3] ==> ['register application', 'send decision e-mail'], [4] [2, 0.02]
# ['send decision e-mail']  [4] ==> ['register application', 'send decision e-mail'], [4] [2, 0.02]
# ['send decision e-mail']  [5] ==> ['register application', 'send decision e-mail'], [4] [2, 0.02]
# ['send decision e-mail']  [1] ==> ['register application', 'send decision e-mail'], [5] [2, 0.02]
# ['send decision e-mail']  [2] ==> ['register application', 'send decision e-mail'], [5] [2, 0.02]
# ['send decision e-mail']  [3] ==> ['register application', 'send decision e-mail'], [5] [2, 0.02]
# ['send decision e-mail']  [4] ==> ['register application', 'send decision e-mail'], [5] [2, 0.02]
# ['send decision e-mail']  [5] ==> ['register application', 'send decision e-mail'], [5] [2, 0.02]
# ['register application']  [1] ==> ['register application', 'reject'], [4] [3, 0.01]
# ['register application']  [2] ==> ['register application', 'reject'], [4] [3, 0.01]
# ['register application']  [3] ==> ['register application', 'reject'], [4] [3, 0.01]
# ['register application']  [4] ==> ['register application', 'reject'], [4] [3, 0.01]
# ['register application']  [5] ==> ['register application', 'reject'], [4] [3, 0.01]
# ['register application']  [1] ==> ['register application', 'reject'], [5] [4, 0.02]
# ['register application']  [2] ==> ['register application', 'reject'], [5] [4, 0.02]
# ['register application']  [3] ==> ['register application', 'reject'], [5] [4, 0.02]
# ['register application']  [4] ==> ['register application', 'reject'], [5] [4, 0.02]
# ['register application']  [5] ==> ['register application', 'reject'], [5] [4, 0.02]
# ['reject']  [1] ==> ['register application', 'reject'], [4] [3, 0.025]
# ['reject']  [2] ==> ['register application', 'reject'], [4] [3, 0.025]
# ['reject']  [3] ==> ['register application', 'reject'], [4] [3, 0.025]
# ['reject']  [4] ==> ['register application', 'reject'], [4] [3, 0.025]
# ['reject']  [5] ==> ['register application', 'reject'], [4] [3, 0.025]
# ['reject']  [1] ==> ['register application', 'reject'], [5] [4, 0.025]
# ['reject']  [2] ==> ['register application', 'reject'], [5] [4, 0.025]
# ['reject']  [3] ==> ['register application', 'reject'], [5] [4, 0.025]
# ['reject']  [4] ==> ['register application', 'reject'], [5] [4, 0.025]
# ['reject']  [5] ==> ['register application', 'reject'], [5] [4, 0.025]
# ['check credit']  [1] ==> ['check credit', 'calculate capacity'], [1] [1, 0.01]
# ['check credit']  [2] ==> ['check credit', 'calculate capacity'], [1] [1, 0.01]
# ['check credit']  [3] ==> ['check credit', 'calculate capacity'], [1] [1, 0.01]
# ['check credit']  [4] ==> ['check credit', 'calculate capacity'], [1] [1, 0.01]
# ['check credit']  [5] ==> ['check credit', 'calculate capacity'], [1] [1, 0.01]
# ['check credit']  [1] ==> ['check credit', 'calculate capacity'], [2] [2, 0.01]
# ['check credit']  [2] ==> ['check credit', 'calculate capacity'], [2] [2, 0.01]
# ['check credit']  [3] ==> ['check credit', 'calculate capacity'], [2] [2, 0.01]
# ['check credit']  [4] ==> ['check credit', 'calculate capacity'], [2] [2, 0.01]
# ['check credit']  [5] ==> ['check credit', 'calculate capacity'], [2] [2, 0.01]
# ['check credit']  [1] ==> ['check credit', 'calculate capacity'], [3] [2, 0.01]
# ['check credit']  [2] ==> ['check credit', 'calculate capacity'], [3] [2, 0.01]
# ['check credit']  [3] ==> ['check credit', 'calculate capacity'], [3] [2, 0.01]
# ['check credit']  [4] ==> ['check credit', 'calculate capacity'], [3] [2, 0.01]
# ['check credit']  [5] ==> ['check credit', 'calculate capacity'], [3] [2, 0.01]
# ['check credit']  [1] ==> ['check credit', 'calculate capacity'], [4] [2, 0.01]
# ['check credit']  [2] ==> ['check credit', 'calculate capacity'], [4] [2, 0.01]
# ['check credit']  [3] ==> ['check credit', 'calculate capacity'], [4] [2, 0.01]
# ['check credit']  [4] ==> ['check credit', 'calculate capacity'], [4] [2, 0.01]
# ['check credit']  [5] ==> ['check credit', 'calculate capacity'], [4] [2, 0.01]
# ['check credit']  [1] ==> ['check credit', 'calculate capacity'], [5] [2, 0.01]
# ['check credit']  [2] ==> ['check credit', 'calculate capacity'], [5] [2, 0.01]
# ['check credit']  [3] ==> ['check credit', 'calculate capacity'], [5] [2, 0.01]
# ['check credit']  [4] ==> ['check credit', 'calculate capacity'], [5] [2, 0.01]
# ['check credit']  [5] ==> ['check credit', 'calculate capacity'], [5] [2, 0.01]
# ['calculate capacity']  [1] ==> ['check credit', 'calculate capacity'], [1] [1, 0.01]
# ['calculate capacity']  [2] ==> ['check credit', 'calculate capacity'], [1] [1, 0.01]
# ['calculate capacity']  [3] ==> ['check credit', 'calculate capacity'], [1] [1, 0.01]
# ['calculate capacity']  [4] ==> ['check credit', 'calculate capacity'], [1] [1, 0.01]
# ['calculate capacity']  [5] ==> ['check credit', 'calculate capacity'], [1] [1, 0.01]
# ['calculate capacity']  [1] ==> ['check credit', 'calculate capacity'], [2] [2, 0.02]
# ['calculate capacity']  [2] ==> ['check credit', 'calculate capacity'], [2] [2, 0.02]
# ['calculate capacity']  [3] ==> ['check credit', 'calculate capacity'], [2] [2, 0.02]
# ['calculate capacity']  [4] ==> ['check credit', 'calculate capacity'], [2] [2, 0.02]
# ['calculate capacity']  [5] ==> ['check credit', 'calculate capacity'], [2] [2, 0.02]
# ['calculate capacity']  [1] ==> ['check credit', 'calculate capacity'], [3] [2, 0.02]
# ['calculate capacity']  [2] ==> ['check credit', 'calculate capacity'], [3] [2, 0.02]
# ['calculate capacity']  [3] ==> ['check credit', 'calculate capacity'], [3] [2, 0.02]
# ['calculate capacity']  [4] ==> ['check credit', 'calculate capacity'], [3] [2, 0.02]
# ['calculate capacity']  [5] ==> ['check credit', 'calculate capacity'], [3] [2, 0.02]
# ['calculate capacity']  [1] ==> ['check credit', 'calculate capacity'], [4] [2, 0.02]
# ['calculate capacity']  [2] ==> ['check credit', 'calculate capacity'], [4] [2, 0.02]
# ['calculate capacity']  [3] ==> ['check credit', 'calculate capacity'], [4] [2, 0.02]
# ['calculate capacity']  [4] ==> ['check credit', 'calculate capacity'], [4] [2, 0.02]
# ['calculate capacity']  [5] ==> ['check credit', 'calculate capacity'], [4] [2, 0.02]
# ['calculate capacity']  [1] ==> ['check credit', 'calculate capacity'], [5] [2, 0.02]
# ['calculate capacity']  [2] ==> ['check credit', 'calculate capacity'], [5] [2, 0.02]
# ['calculate capacity']  [3] ==> ['check credit', 'calculate capacity'], [5] [2, 0.02]
# ['calculate capacity']  [4] ==> ['check credit', 'calculate capacity'], [5] [2, 0.02]
# ['calculate capacity']  [5] ==> ['check credit', 'calculate capacity'], [5] [2, 0.02]
# ['check credit']  [1] ==> ['check credit', 'send decision e-mail'], [3] [1, 0.01]
# ['check credit']  [2] ==> ['check credit', 'send decision e-mail'], [3] [1, 0.01]
# ['check credit']  [3] ==> ['check credit', 'send decision e-mail'], [3] [1, 0.01]
# ['check credit']  [4] ==> ['check credit', 'send decision e-mail'], [3] [1, 0.01]
# ['check credit']  [5] ==> ['check credit', 'send decision e-mail'], [3] [1, 0.01]
# ['check credit']  [1] ==> ['check credit', 'send decision e-mail'], [4] [2, 0.01]
# ['check credit']  [2] ==> ['check credit', 'send decision e-mail'], [4] [2, 0.01]
# ['check credit']  [3] ==> ['check credit', 'send decision e-mail'], [4] [2, 0.01]
# ['check credit']  [4] ==> ['check credit', 'send decision e-mail'], [4] [2, 0.01]
# ['check credit']  [5] ==> ['check credit', 'send decision e-mail'], [4] [2, 0.01]
# ['check credit']  [1] ==> ['check credit', 'send decision e-mail'], [5] [3, 0.02]
# ['check credit']  [2] ==> ['check credit', 'send decision e-mail'], [5] [3, 0.02]
# ['check credit']  [3] ==> ['check credit', 'send decision e-mail'], [5] [3, 0.02]
# ['check credit']  [4] ==> ['check credit', 'send decision e-mail'], [5] [3, 0.02]
# ['check credit']  [5] ==> ['check credit', 'send decision e-mail'], [5] [3, 0.02]
# ['send decision e-mail']  [1] ==> ['check credit', 'send decision e-mail'], [4] [2, 0.01]
# ['send decision e-mail']  [2] ==> ['check credit', 'send decision e-mail'], [4] [2, 0.01]
# ['send decision e-mail']  [3] ==> ['check credit', 'send decision e-mail'], [4] [2, 0.01]
# ['send decision e-mail']  [4] ==> ['check credit', 'send decision e-mail'], [4] [2, 0.01]
# ['send decision e-mail']  [5] ==> ['check credit', 'send decision e-mail'], [4] [2, 0.01]
# ['send decision e-mail']  [1] ==> ['check credit', 'send decision e-mail'], [5] [3, 0.01]
# ['send decision e-mail']  [2] ==> ['check credit', 'send decision e-mail'], [5] [3, 0.01]
# ['send decision e-mail']  [3] ==> ['check credit', 'send decision e-mail'], [5] [3, 0.01]
# ['send decision e-mail']  [4] ==> ['check credit', 'send decision e-mail'], [5] [3, 0.01]
# ['send decision e-mail']  [5] ==> ['check credit', 'send decision e-mail'], [5] [3, 0.01]
# ['calculate capacity']  [1] ==> ['calculate capacity', 'accept'], [5] [2, 0.01]
# ['calculate capacity']  [2] ==> ['calculate capacity', 'accept'], [5] [2, 0.01]
# ['calculate capacity']  [3] ==> ['calculate capacity', 'accept'], [5] [2, 0.01]
# ['calculate capacity']  [4] ==> ['calculate capacity', 'accept'], [5] [2, 0.01]
# ['calculate capacity']  [5] ==> ['calculate capacity', 'accept'], [5] [2, 0.01]
# ['accept']  [1] ==> ['calculate capacity', 'accept'], [5] [2, 0.05]
# ['accept']  [2] ==> ['calculate capacity', 'accept'], [5] [2, 0.05]
# ['accept']  [3] ==> ['calculate capacity', 'accept'], [5] [2, 0.05]
# ['accept']  [4] ==> ['calculate capacity', 'accept'], [5] [2, 0.05]
# ['accept']  [5] ==> ['calculate capacity', 'accept'], [5] [2, 0.05]
# ['calculate capacity']  [1] ==> ['calculate capacity', 'send decision e-mail'], [1] [1, 0.01]
# ['calculate capacity']  [2] ==> ['calculate capacity', 'send decision e-mail'], [1] [1, 0.01]
# ['calculate capacity']  [3] ==> ['calculate capacity', 'send decision e-mail'], [1] [1, 0.01]
# ['calculate capacity']  [4] ==> ['calculate capacity', 'send decision e-mail'], [1] [1, 0.01]
# ['calculate capacity']  [5] ==> ['calculate capacity', 'send decision e-mail'], [1] [1, 0.01]
# ['calculate capacity']  [1] ==> ['calculate capacity', 'send decision e-mail'], [2] [1, 0.01]
# ['calculate capacity']  [2] ==> ['calculate capacity', 'send decision e-mail'], [2] [1, 0.01]
# ['calculate capacity']  [3] ==> ['calculate capacity', 'send decision e-mail'], [2] [1, 0.01]
# ['calculate capacity']  [4] ==> ['calculate capacity', 'send decision e-mail'], [2] [1, 0.01]
# ['calculate capacity']  [5] ==> ['calculate capacity', 'send decision e-mail'], [2] [1, 0.01]
# ['calculate capacity']  [1] ==> ['calculate capacity', 'send decision e-mail'], [3] [1, 0.01]
# ['calculate capacity']  [2] ==> ['calculate capacity', 'send decision e-mail'], [3] [1, 0.01]
# ['calculate capacity']  [3] ==> ['calculate capacity', 'send decision e-mail'], [3] [1, 0.01]
# ['calculate capacity']  [4] ==> ['calculate capacity', 'send decision e-mail'], [3] [1, 0.01]
# ['calculate capacity']  [5] ==> ['calculate capacity', 'send decision e-mail'], [3] [1, 0.01]
# ['calculate capacity']  [1] ==> ['calculate capacity', 'send decision e-mail'], [4] [2, 0.01]
# ['calculate capacity']  [2] ==> ['calculate capacity', 'send decision e-mail'], [4] [2, 0.01]
# ['calculate capacity']  [3] ==> ['calculate capacity', 'send decision e-mail'], [4] [2, 0.01]
# ['calculate capacity']  [4] ==> ['calculate capacity', 'send decision e-mail'], [4] [2, 0.01]
# ['calculate capacity']  [5] ==> ['calculate capacity', 'send decision e-mail'], [4] [2, 0.01]
# ['calculate capacity']  [1] ==> ['calculate capacity', 'send decision e-mail'], [5] [2, 0.01]
# ['calculate capacity']  [2] ==> ['calculate capacity', 'send decision e-mail'], [5] [2, 0.01]
# ['calculate capacity']  [3] ==> ['calculate capacity', 'send decision e-mail'], [5] [2, 0.01]
# ['calculate capacity']  [4] ==> ['calculate capacity', 'send decision e-mail'], [5] [2, 0.01]
# ['calculate capacity']  [5] ==> ['calculate capacity', 'send decision e-mail'], [5] [2, 0.01]
# ['send decision e-mail']  [1] ==> ['calculate capacity', 'send decision e-mail'], [1] [1, 0.01]
# ['send decision e-mail']  [2] ==> ['calculate capacity', 'send decision e-mail'], [1] [1, 0.01]
# ['send decision e-mail']  [3] ==> ['calculate capacity', 'send decision e-mail'], [1] [1, 0.01]
# ['send decision e-mail']  [4] ==> ['calculate capacity', 'send decision e-mail'], [1] [1, 0.01]
# ['send decision e-mail']  [5] ==> ['calculate capacity', 'send decision e-mail'], [1] [1, 0.01]
# ['send decision e-mail']  [1] ==> ['calculate capacity', 'send decision e-mail'], [2] [1, 0.01]
# ['send decision e-mail']  [2] ==> ['calculate capacity', 'send decision e-mail'], [2] [1, 0.01]
# ['send decision e-mail']  [3] ==> ['calculate capacity', 'send decision e-mail'], [2] [1, 0.01]
# ['send decision e-mail']  [4] ==> ['calculate capacity', 'send decision e-mail'], [2] [1, 0.01]
# ['send decision e-mail']  [5] ==> ['calculate capacity', 'send decision e-mail'], [2] [1, 0.01]
# ['send decision e-mail']  [1] ==> ['calculate capacity', 'send decision e-mail'], [3] [1, 0.01]
# ['send decision e-mail']  [2] ==> ['calculate capacity', 'send decision e-mail'], [3] [1, 0.01]
# ['send decision e-mail']  [3] ==> ['calculate capacity', 'send decision e-mail'], [3] [1, 0.01]
# ['send decision e-mail']  [4] ==> ['calculate capacity', 'send decision e-mail'], [3] [1, 0.01]
# ['send decision e-mail']  [5] ==> ['calculate capacity', 'send decision e-mail'], [3] [1, 0.01]
# ['send decision e-mail']  [1] ==> ['calculate capacity', 'send decision e-mail'], [4] [2, 0.02]
# ['send decision e-mail']  [2] ==> ['calculate capacity', 'send decision e-mail'], [4] [2, 0.02]
# ['send decision e-mail']  [3] ==> ['calculate capacity', 'send decision e-mail'], [4] [2, 0.02]
# ['send decision e-mail']  [4] ==> ['calculate capacity', 'send decision e-mail'], [4] [2, 0.02]
# ['send decision e-mail']  [5] ==> ['calculate capacity', 'send decision e-mail'], [4] [2, 0.02]
# ['send decision e-mail']  [1] ==> ['calculate capacity', 'send decision e-mail'], [5] [2, 0.02]
# ['send decision e-mail']  [2] ==> ['calculate capacity', 'send decision e-mail'], [5] [2, 0.02]
# ['send decision e-mail']  [3] ==> ['calculate capacity', 'send decision e-mail'], [5] [2, 0.02]
# ['send decision e-mail']  [4] ==> ['calculate capacity', 'send decision e-mail'], [5] [2, 0.02]
# ['send decision e-mail']  [5] ==> ['calculate capacity', 'send decision e-mail'], [5] [2, 0.02]
# ['calculate capacity']  [1] ==> ['calculate capacity', 'reject'], [2] [1, 0.01]
# ['calculate capacity']  [2] ==> ['calculate capacity', 'reject'], [2] [1, 0.01]
# ['calculate capacity']  [3] ==> ['calculate capacity', 'reject'], [2] [1, 0.01]
# ['calculate capacity']  [4] ==> ['calculate capacity', 'reject'], [2] [1, 0.01]
# ['calculate capacity']  [5] ==> ['calculate capacity', 'reject'], [2] [1, 0.01]
# ['calculate capacity']  [1] ==> ['calculate capacity', 'reject'], [3] [1, 0.01]
# ['calculate capacity']  [2] ==> ['calculate capacity', 'reject'], [3] [1, 0.01]
# ['calculate capacity']  [3] ==> ['calculate capacity', 'reject'], [3] [1, 0.01]
# ['calculate capacity']  [4] ==> ['calculate capacity', 'reject'], [3] [1, 0.01]
# ['calculate capacity']  [5] ==> ['calculate capacity', 'reject'], [3] [1, 0.01]
# ['calculate capacity']  [1] ==> ['calculate capacity', 'reject'], [4] [2, 0.02]
# ['calculate capacity']  [2] ==> ['calculate capacity', 'reject'], [4] [2, 0.02]
# ['calculate capacity']  [3] ==> ['calculate capacity', 'reject'], [4] [2, 0.02]
# ['calculate capacity']  [4] ==> ['calculate capacity', 'reject'], [4] [2, 0.02]
# ['calculate capacity']  [5] ==> ['calculate capacity', 'reject'], [4] [2, 0.02]
# ['calculate capacity']  [1] ==> ['calculate capacity', 'reject'], [5] [2, 0.02]
# ['calculate capacity']  [2] ==> ['calculate capacity', 'reject'], [5] [2, 0.02]
# ['calculate capacity']  [3] ==> ['calculate capacity', 'reject'], [5] [2, 0.02]
# ['calculate capacity']  [4] ==> ['calculate capacity', 'reject'], [5] [2, 0.02]
# ['calculate capacity']  [5] ==> ['calculate capacity', 'reject'], [5] [2, 0.02]
# ['check system']  [1] ==> ['check system', 'send decision e-mail'], [1] [1, 0.011235955056179775]
# ['check system']  [2] ==> ['check system', 'send decision e-mail'], [1] [1, 0.011235955056179775]
# ['check system']  [3] ==> ['check system', 'send decision e-mail'], [1] [1, 0.011235955056179775]
# ['check system']  [4] ==> ['check system', 'send decision e-mail'], [1] [1, 0.011235955056179775]
# ['check system']  [5] ==> ['check system', 'send decision e-mail'], [1] [1, 0.011235955056179775]
# ['check system']  [1] ==> ['check system', 'send decision e-mail'], [2] [2, 0.011235955056179775]
# ['check system']  [2] ==> ['check system', 'send decision e-mail'], [2] [2, 0.011235955056179775]
# ['check system']  [3] ==> ['check system', 'send decision e-mail'], [2] [2, 0.011235955056179775]
# ['check system']  [4] ==> ['check system', 'send decision e-mail'], [2] [2, 0.011235955056179775]
# ['check system']  [5] ==> ['check system', 'send decision e-mail'], [2] [2, 0.011235955056179775]
# ['check system']  [1] ==> ['check system', 'send decision e-mail'], [3] [2, 0.011235955056179775]
# ['check system']  [2] ==> ['check system', 'send decision e-mail'], [3] [2, 0.011235955056179775]
# ['check system']  [3] ==> ['check system', 'send decision e-mail'], [3] [2, 0.011235955056179775]
# ['check system']  [4] ==> ['check system', 'send decision e-mail'], [3] [2, 0.011235955056179775]
# ['check system']  [5] ==> ['check system', 'send decision e-mail'], [3] [2, 0.011235955056179775]
# ['check system']  [1] ==> ['check system', 'send decision e-mail'], [4] [3, 0.02247191011235955]
# ['check system']  [2] ==> ['check system', 'send decision e-mail'], [4] [3, 0.02247191011235955]
# ['check system']  [3] ==> ['check system', 'send decision e-mail'], [4] [3, 0.02247191011235955]
# ['check system']  [4] ==> ['check system', 'send decision e-mail'], [4] [3, 0.02247191011235955]
# ['check system']  [5] ==> ['check system', 'send decision e-mail'], [4] [3, 0.02247191011235955]
# ['check system']  [1] ==> ['check system', 'send decision e-mail'], [5] [3, 0.02247191011235955]
# ['check system']  [2] ==> ['check system', 'send decision e-mail'], [5] [3, 0.02247191011235955]
# ['check system']  [3] ==> ['check system', 'send decision e-mail'], [5] [3, 0.02247191011235955]
# ['check system']  [4] ==> ['check system', 'send decision e-mail'], [5] [3, 0.02247191011235955]
# ['check system']  [5] ==> ['check system', 'send decision e-mail'], [5] [3, 0.02247191011235955]
# ['send decision e-mail']  [1] ==> ['check system', 'send decision e-mail'], [1] [1, 0.01]
# ['send decision e-mail']  [2] ==> ['check system', 'send decision e-mail'], [1] [1, 0.01]
# ['send decision e-mail']  [3] ==> ['check system', 'send decision e-mail'], [1] [1, 0.01]
# ['send decision e-mail']  [4] ==> ['check system', 'send decision e-mail'], [1] [1, 0.01]
# ['send decision e-mail']  [5] ==> ['check system', 'send decision e-mail'], [1] [1, 0.01]
# ['send decision e-mail']  [1] ==> ['check system', 'send decision e-mail'], [2] [2, 0.02]
# ['send decision e-mail']  [2] ==> ['check system', 'send decision e-mail'], [2] [2, 0.02]
# ['send decision e-mail']  [3] ==> ['check system', 'send decision e-mail'], [2] [2, 0.02]
# ['send decision e-mail']  [4] ==> ['check system', 'send decision e-mail'], [2] [2, 0.02]
# ['send decision e-mail']  [5] ==> ['check system', 'send decision e-mail'], [2] [2, 0.02]
# ['send decision e-mail']  [1] ==> ['check system', 'send decision e-mail'], [3] [2, 0.02]
# ['send decision e-mail']  [2] ==> ['check system', 'send decision e-mail'], [3] [2, 0.02]
# ['send decision e-mail']  [3] ==> ['check system', 'send decision e-mail'], [3] [2, 0.02]
# ['send decision e-mail']  [4] ==> ['check system', 'send decision e-mail'], [3] [2, 0.02]
# ['send decision e-mail']  [5] ==> ['check system', 'send decision e-mail'], [3] [2, 0.02]
# ['send decision e-mail']  [1] ==> ['check system', 'send decision e-mail'], [4] [3, 0.02]
# ['send decision e-mail']  [2] ==> ['check system', 'send decision e-mail'], [4] [3, 0.02]
# ['send decision e-mail']  [3] ==> ['check system', 'send decision e-mail'], [4] [3, 0.02]
# ['send decision e-mail']  [4] ==> ['check system', 'send decision e-mail'], [4] [3, 0.02]
# ['send decision e-mail']  [5] ==> ['check system', 'send decision e-mail'], [4] [3, 0.02]
# ['send decision e-mail']  [1] ==> ['check system', 'send decision e-mail'], [5] [3, 0.02]
# ['send decision e-mail']  [2] ==> ['check system', 'send decision e-mail'], [5] [3, 0.02]
# ['send decision e-mail']  [3] ==> ['check system', 'send decision e-mail'], [5] [3, 0.02]
# ['send decision e-mail']  [4] ==> ['check system', 'send decision e-mail'], [5] [3, 0.02]
# ['send decision e-mail']  [5] ==> ['check system', 'send decision e-mail'], [5] [3, 0.02]
# ['check system']  [1] ==> ['check system', 'reject'], [2] [2, 0.011235955056179775]
# ['check system']  [2] ==> ['check system', 'reject'], [2] [2, 0.011235955056179775]
# ['check system']  [3] ==> ['check system', 'reject'], [2] [2, 0.011235955056179775]
# ['check system']  [4] ==> ['check system', 'reject'], [2] [2, 0.011235955056179775]
# ['check system']  [5] ==> ['check system', 'reject'], [2] [2, 0.011235955056179775]
# ['check system']  [1] ==> ['check system', 'reject'], [3] [3, 0.02247191011235955]
# ['check system']  [2] ==> ['check system', 'reject'], [3] [3, 0.02247191011235955]
# ['check system']  [3] ==> ['check system', 'reject'], [3] [3, 0.02247191011235955]
# ['check system']  [4] ==> ['check system', 'reject'], [3] [3, 0.02247191011235955]
# ['check system']  [5] ==> ['check system', 'reject'], [3] [3, 0.02247191011235955]
# ['check system']  [1] ==> ['check system', 'reject'], [4] [5, 0.033707865168539325]
# ['check system']  [2] ==> ['check system', 'reject'], [4] [5, 0.033707865168539325]
# ['check system']  [3] ==> ['check system', 'reject'], [4] [5, 0.033707865168539325]
# ['check system']  [4] ==> ['check system', 'reject'], [4] [5, 0.033707865168539325]
# ['check system']  [5] ==> ['check system', 'reject'], [4] [5, 0.033707865168539325]
# ['check system']  [1] ==> ['check system', 'reject'], [5] [5, 0.033707865168539325]
# ['check system']  [2] ==> ['check system', 'reject'], [5] [5, 0.033707865168539325]
# ['check system']  [3] ==> ['check system', 'reject'], [5] [5, 0.033707865168539325]
# ['check system']  [4] ==> ['check system', 'reject'], [5] [5, 0.033707865168539325]
# ['check system']  [5] ==> ['check system', 'reject'], [5] [5, 0.033707865168539325]
# ['reject']  [1] ==> ['check system', 'reject'], [2] [2, 0.0125]
# ['reject']  [2] ==> ['check system', 'reject'], [2] [2, 0.0125]
# ['reject']  [3] ==> ['check system', 'reject'], [2] [2, 0.0125]
# ['reject']  [4] ==> ['check system', 'reject'], [2] [2, 0.0125]
# ['reject']  [5] ==> ['check system', 'reject'], [2] [2, 0.0125]
# ['reject']  [1] ==> ['check system', 'reject'], [3] [3, 0.0125]
# ['reject']  [2] ==> ['check system', 'reject'], [3] [3, 0.0125]
# ['reject']  [3] ==> ['check system', 'reject'], [3] [3, 0.0125]
# ['reject']  [4] ==> ['check system', 'reject'], [3] [3, 0.0125]
# ['reject']  [5] ==> ['check system', 'reject'], [3] [3, 0.0125]
# ['reject']  [1] ==> ['check system', 'reject'], [4] [5, 0.025]
# ['reject']  [2] ==> ['check system', 'reject'], [4] [5, 0.025]
# ['reject']  [3] ==> ['check system', 'reject'], [4] [5, 0.025]
# ['reject']  [4] ==> ['check system', 'reject'], [4] [5, 0.025]
# ['reject']  [5] ==> ['check system', 'reject'], [4] [5, 0.025]
# ['reject']  [1] ==> ['check system', 'reject'], [5] [5, 0.025]
# ['reject']  [2] ==> ['check system', 'reject'], [5] [5, 0.025]
# ['reject']  [3] ==> ['check system', 'reject'], [5] [5, 0.025]
# ['reject']  [4] ==> ['check system', 'reject'], [5] [5, 0.025]
# ['reject']  [5] ==> ['check system', 'reject'], [5] [5, 0.025]
